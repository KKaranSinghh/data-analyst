# %%
import pandas as pd

# %% [markdown]
# - How to creat dataset in different ways
#   - dictionary of items
#   - list of items
#   - importing csv files
#   - importing excel files
#   - importing json files
# - read dataframe
# - selection of data
# - manipulating the data
# - visualizing the data
# - loading the data

# %%
# to frame data (dictionary)

books = {
    'title' : ['great expectations', 'to kill a mockingbird','pride and prejudice', ' the book thief'],
    'author' : ['charles dickens', 'harper lee','jane austen', 'markus zusak'],
    'published' : [1861, 1960, 1813, 2005],
    'price' : [399, 1099, 199, 500]
}
pd.DataFrame(books)
# Out:
#                    title           author  published  price
# 0     great expectations  charles dickens       1861    399
# 1  to kill a mockingbird       harper lee       1960   1099
# 2    pride and prejudice      jane austen       1813    199
# 3         the book thief     markus zusak       2005    500

# %%
# frame the data (List)

movie = [
    {'title' : 'stree', 'director' : 'jonny', 'length' : 129},
    {'title' : 'I', 'director' : 'Raj', 'length' : 131},
    {'title' : 'robot', 'director' : 'rohit', 'length' : 118},
    {'title' : 'tiger', 'director' : 'salman', 'length' : 300}
]
pd.DataFrame(movie)
# Out:
#    title director  length
# 0  stree    jonny     129
# 1      I      Raj     131
# 2  robot    rohit     118
# 3  tiger   salman     300

# %%
# to get online data
url = 'https://raw.githubusercontent.com/digipodium/Datasets/main/regression/kc_house_data.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.head()  # it will show by defalt top 5 rows
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.head(15) # to get more than top 5 rows we have to give the row numbers
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  20141013T000000   221900.0         3       1.00         1180
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 2   5631500400  20150225T000000   180000.0         2       1.00          770
# 3   2487200875  20141209T000000   604000.0         4       3.00         1960
# 4   1954400510  20150218T000000   510000.0         3       2.00         1680
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6   1321400060  20140627T000000   257500.0         3       2.25         1715
# 7   2008000270  20150115T000000   291850.0         3       1.50         1060
# 8   2414600126  20150415T000000   229500.0         3       1.00         1780
# 9   3793500160  20150312T000000   323000.0         3       2.50         1890
# 10  1736800520  20150403T000000   662500.0         3       2.50         3560
# ...

# %%
df.tail()  # it will show you last 5 rows by defalt
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
df.sample()     # it will give you randome one sample
df.sample(4)    # it will give you randome 4 samples
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 16479  1245500725  20141030T000000  675000.0         3       1.75
# 20698   255470030  20150429T000000  619990.0         4       2.75
# 8873   2660500365  20150106T000000  392000.0         3       1.00
# 13999  1241500155  20140805T000000  575000.0         3       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 16479         1240     13869     1.0           0     0  ...      7
# 20698         2630      4501     2.0           0     0  ...      8
# 8873          1230      9600     1.0           0     0  ...      7
# 13999         2070      3599     2.0           0     0  ...      8
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 16479        1240              0      1957             0    98033  47.6919
# 20698        2630              0      2015             0    98028  47.7748
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe(include="object")   # to get perticular information about data
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %%
df.shape    # to print only the number of rows and columns
# Out:
# (21613, 21)

# %%
df.columns    # to get the columns in our data
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.columns.tolist()    # to get the columns in our data in structured manner
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %% [markdown]
# ## selecting data in pandas
# - row wise
#   - iloc - index based location
#   - loc - lable based location
#
# - column wise
#   - single column selection
#   - multiple column selection

# %%
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df.iloc[4] # to get particular data
# Out:
# id                    1954400510
# date             20150218T000000
# price                   510000.0
# bedrooms                       3
# bathrooms                    2.0
# sqft_living                 1680
# sqft_lot                    8080
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      3
# grade                          8
# sqft_above                  1680
# sqft_basement                  0
# yr_built                    1987
# yr_renovated                   0
# zipcode                    98074
# lat                      47.6168
# long                    -122.045
# sqft_living15               1800
# sqft_lot15                  7503
# Name: 4, dtype: object

# %%
df.iloc[[1,5,45,34]]  # to get multiple rows of data according to index number
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 1   6414100192  20141209T000000   538000.0         3       2.25         2570
# 5   7237550310  20140512T000000  1225000.0         4       4.50         5420
# 45  8035350320  20140718T000000   488000.0         3       2.50         3160
# 34  7955080270  20141203T000000   322500.0         4       2.75         2060
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 1       7242     2.0           0     0  ...      7        2170            400
# 5     101930     1.0           0     0  ...     11        3890           1530
# 45     13603     2.0           0     0  ...      8        3160              0
# 34      6659     1.0           0     0  ...      7        1280            780
#
#     yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 1       1951          1991    98125  47.7210 -122.319           1690
# ...

# %%
df.iloc[[1,10,34],[0,1,2,3,5,9]]   # to get different rows and columns according to choice
# Out:
#             id             date     price  bedrooms  sqft_living  view
# 1   6414100192  20141209T000000  538000.0         3         2570     0
# 10  1736800520  20150403T000000  662500.0         3         3560     0
# 34  7955080270  20141203T000000  322500.0         4         2060     0

# %%
df.iloc[34 : 50, 0 : 10]       # (slicer) to get data in a
# Out:
#             id             date      price  bedrooms  bathrooms  sqft_living  \
# 34  7955080270  20141203T000000   322500.0         4       2.75         2060
# 35  9547205180  20140613T000000   696000.0         3       2.50         2300
# 36  9435300030  20140528T000000   550000.0         4       1.00         1660
# 37  2768000400  20141230T000000   640000.0         4       2.00         2360
# 38  7895500070  20150213T000000   240000.0         4       1.00         1220
# 39  2078500320  20140620T000000   605000.0         4       2.50         2620
# 40  5547700270  20140715T000000   625000.0         4       2.50         2570
# 41  7766200013  20140811T000000   775000.0         4       2.25         4220
# 42  7203220400  20140707T000000   861990.0         5       2.75         3595
# 43  9270200160  20141028T000000   685000.0         3       1.00         1570
# 44  1432701230  20140729T000000   309000.0         3       1.00         1280
# ...

# %%
df = df.set_index('id')    # to set any column as an index which have uique numbers (ex:- id)
df.head()
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 7129300520      5650     1.0           0     0          3      7        1180
# 6414100192      7242     2.0           0     0          3      7        2170
# 5631500400     10000     1.0           0     0          3      6         770
# 2487200875      5000     1.0           0     0          5      7        1050
# 1954400510      8080     1.0           0     0          3      8        1680
#
# ...

# %%
df.loc[[6414100192, 1954400510, 8035350320]]       # to get different data by id which we set as index
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# 8035350320  20140718T000000  488000.0         3       2.50         3160
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# 6414100192      7242     2.0           0     0          3      7        2170
# 1954400510      8080     1.0           0     0          3      8        1680
# 8035350320     13603     2.0           0     0          3      8        3160
#
#             sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# id
# 6414100192            400      1951          1991    98125  47.7210 -122.319
# 1954400510              0      1987             0    98074  47.6168 -122.045
# 8035350320              0      2003             0    98019  47.7443 -121.977
#
#             sqft_living15  sqft_lot15
# ...

# %% [markdown]
# ## Single column selection
# - dictionary like selection
#     - dataframe['column_name']
# - object like selection
#     - dtaframe.column_name
#
# ## multiple column selection
# - dictionary like seleciton
#     - dataframe[[list_of_molumn_names]]

# %%
df['price']
# Out:
# id
# 7129300520    221900.0
# 6414100192    538000.0
# 5631500400    180000.0
# 2487200875    604000.0
# 1954400510    510000.0
#                 ...
# 263000018     360000.0
# 6600060120    400000.0
# 1523300141    402101.0
# 291310100     400000.0
# 1523300157    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df[['price','bedrooms','bathrooms']]
# Out:
#                price  bedrooms  bathrooms
# id
# 7129300520  221900.0         3       1.00
# 6414100192  538000.0         3       2.25
# 5631500400  180000.0         2       1.00
# 2487200875  604000.0         4       3.00
# 1954400510  510000.0         3       2.00
# ...              ...       ...        ...
# 263000018   360000.0         3       2.50
# 6600060120  400000.0         4       2.50
# 1523300141  402101.0         2       0.75
# 291310100   400000.0         3       2.50
# 1523300157  325000.0         2       0.75
#
# [21613 rows x 3 columns]

# %% [markdown]
# ## Manipulating and Cleaning Data
# - removing rows and columns
# - rename column names
# - adding columns
# - changing datatypes
# - handling missing values
# - dropping missing values
# - using apply() methods

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
#        'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# to removing rows
df.drop(7129300520)
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 2487200875  20141209T000000   604000.0         4       3.00         1960
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
# for remove multiple rows
df.drop(labels=[7129300520,2487200875])
# Out:
#                        date      price  bedrooms  bathrooms  sqft_living  \
# id
# 6414100192  20141209T000000   538000.0         3       2.25         2570
# 5631500400  20150225T000000   180000.0         2       1.00          770
# 1954400510  20150218T000000   510000.0         3       2.00         1680
# 7237550310  20140512T000000  1225000.0         4       4.50         5420
# 1321400060  20140627T000000   257500.0         3       2.25         1715
# ...                     ...        ...       ...        ...          ...
# 263000018   20140521T000000   360000.0         3       2.50         1530
# 6600060120  20150223T000000   400000.0         4       2.50         2310
# 1523300141  20140623T000000   402101.0         2       0.75         1020
# 291310100   20150116T000000   400000.0         3       2.50         1600
# 1523300157  20141015T000000   325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
# to remove columns
cols_to_drop = ['sqft_living15','sqft_lot15']
df.drop(columns=cols_to_drop)
# Out:
#                        date     price  bedrooms  bathrooms  sqft_living  \
# id
# 7129300520  20141013T000000  221900.0         3       1.00         1180
# 6414100192  20141209T000000  538000.0         3       2.25         2570
# 5631500400  20150225T000000  180000.0         2       1.00          770
# 2487200875  20141209T000000  604000.0         4       3.00         1960
# 1954400510  20150218T000000  510000.0         3       2.00         1680
# ...                     ...       ...       ...        ...          ...
# 263000018   20140521T000000  360000.0         3       2.50         1530
# 6600060120  20150223T000000  400000.0         4       2.50         2310
# 1523300141  20140623T000000  402101.0         2       0.75         1020
# 291310100   20150116T000000  400000.0         3       2.50         1600
# 1523300157  20141015T000000  325000.0         2       0.75         1020
#
#             sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# id
# ...

# %%
cols_to_drop = ['sqft_living15','sqft_lot15']
df.drop(columns=cols_to_drop, inplace=True)

# (inplace=True) is for delete permanent
